# %% [markdown]
# Answers for Week 1
#
# * Name: Noa Krosse
# * Username: nwmkrosse
# * Student s-number: S6371582
# * Group (AS1, etc.): AS1

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![Puppy.jpeg](attachment:Puppy.jpeg)

# %% [markdown]
# Question 1.3

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1

print(x)
# Out:
# 720

# %% [markdown]
# Question 1.4

# %%
from scipy.constants import c

print(c)

from scipy.constants import h
print(h)
# Out:
# 299792458.0
# 6.62607015e-34

# %%
from scipy.constants import h

f=2.42e28

E=h*f

print(E)
# Out:
# 1.6035089763e-05

# %% [markdown]
# Question 1.5

# %%
from scipy.constants import G

M_Moon=7.342e22
M_Earth=5.9722e24
R=385000.6e3

F=G*M_Moon*M_Earth/R**2

print(F)
# Out:
# 1.974384051807571e+20

# %% [markdown]
# Question 1.6 (Coursework)

# %%
from scipy.constants import G, pi
from scipy.constants import au as a

P=31556926

M=4*(pi**2)*(a**3)/(G*P**2)

print(M)
# Out:
# 1.988569922528084e+30

# %% [markdown]
# Question 1.7

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 10
#
# 3.142857142857143

# %% [markdown]
# Explaination: The code makes the x1 right before the x2. So now it is 10-3.14......  The "" defines the end of the line. Because there is nothing in it, you get that X2 is right behind it.

# %% [markdown]
# Question 1.8 (Coursework)

# %%
# Sirius data

apparentMagnitude = -1.46
absoluteMagnitude = 1.45

# The distance is related to the magnitudes as m-M=5.Log(d/10)
# 1 Parsec = 3.26164 ly

m = float(input("Enter a apparent Magnitude: "))

M = float(input("Enter a absolute Magnitude: "))


m = apparentMagnitude
M = absoluteMagnitude

d = 10.0 * pow( 10.0, (m-M)/5.0 ) * 3.26164

print(d)
# Out:
# Enter a apparent Magnitude: -1.46
# Enter a absolute Magnitude: 1.45
# 8.53957042692737

# %% [markdown]
# QUESTION 1.10

# %%
do here question 10
# Out:
#   Cell In[3], line 1
#     do here question 10
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Question 1.11

# %% [markdown]
# The dot at the end means that you continu the tree from the directory you in. If i would be in PROGNUM then i would and do the commend tree -d . then i would only see the List of Tasks (plus one untitled folder)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 12
